# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests

# %%
# url of the webpage
URL = "https://www.amazon.in/s?k=whey+protein&i=todays-deals&crid=K8YF2KWBRM5A&sprefix=%2Ctodays-deals%2C232&ref=nb_sb_ss_recent_2_0_recent"

# %%
# headers for request
HEADERS = ({'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/129.0.0.0 Safari/537.36','Accept-Language':'en-US, en;q=0.5'})

# %%
#HTTP request
webpage = requests.get(URL, headers=HEADERS)
print(response.status_code)
# Out:
# 200

# %%
# soup object containing all data
soup = BeautifulSoup(webpage.content,"html.parser")

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="a-no-js" data-19ax5a9jf="dingo" lang="en-in">
#  <!-- sp:feature:head-start -->
#  <head>
#   <script>
#    var aPageStart = (new Date()).getTime();
#   </script>
#   <meta charset="utf-8"/>
#   <!-- sp:end-feature:head-start -->
#   <!-- sp:feature:csm:head-open-part1 -->
#   <script type="text/javascript">
#    var ue_t0=ue_t0||+new Date();
#   </script>
#   <!-- sp:end-feature:csm:head-open-part1 -->
#   <!-- sp:feature:cs-optimization -->
#   <meta content="on" http-equiv="x-dns-prefetch-control"/>
#   <link href="https://images-eu.ssl-images-amazon.com" rel="dns-prefetch"/>
#   <link href="https://m.media-amazon.com" rel="dns-prefetch"/>
#   <link href="https://completion.amazon.com" rel="dns-prefetch"/>
#   <!-- sp:end-feature:cs-optimization -->
#   <!-- sp:feature:csm:head-open-part2 -->
#   <script type="text/javascript">
#    window.ue_ihb = (window.ue_ihb || window.ueinit || 0) + 1;
# if (window.ue_ihb === 1) {
#
# var ue_csm = window,
# ...

# %%
name = []

a = soup.find_all('h2',class_="a-size-mini a-spacing-none a-color-base s-line-clamp-2")
for i in a:
    name.append(i.text)
print(name)
len(name)
# Out:
# ['Optimum Nutrition (ON) Gold Standard 100% Whey (2 lbs/907 g) (Double Rich Chocolate) Protein Powder for Muscle Support & Recovery, Vegetarian - Primary Source Whey Isolate  ', 'OPTIMUM NUTRITION Performance Whey Protein Powder Blend with Isolate, 24g Protein, 5g BCAA, Chocolate, 1 kg  ', 'Bigmuscles Nutrition Essential Whey Protein [1Kg,Double Rich Chocolate] |24g Protein per serving with Digestive Enzymes, Vitamin & Minerals, No Added Sugar | Improved Strength,Muscle Building  ', 'Bigmuscles Nutrition Premium Gold Whey [1Kg] | Informed Choice UK Certified | Isolate Whey Protein Blend | 25g Protein | 11g EAA | ProHydrolase Enzyme Technology [Chocolate]  ', 'Optimum Nutrition (ON) Gold Standard 100% Whey Protein Powder - 1 lb (Double Rich Chocolate), Primary Source Isolate  ', 'Bigmuscles Nutrition Crude Whey - 1 kg (Rich Chocolate) | US FDA REGD. BRAND | Whey Protein Concentrate 80%, 24g Protein, 5.5g BCAA, 4 g Glutamine  ', 'The Whole Truth Whey Protein Isolate+Concentrate | Light
# ...

# %%
price = []
b = soup.find_all('span',class_='a-price-whole')
for i in b:
    price.append(i.text.strip())
print(price)    
len(price)
# Out:
# ['3,099', '2,219', '889', '1,499', '1,741', '1,099', '3,099', '1,899', '11,544', '2,095', '1,697', '1,399', '1,029', '1,599', '2,299', '1,599']
# 16

# %%
dict = {'name':name, 'price':price}
df = pd.DataFrame(dict)

# %%
df
# Out:
#                                                  name   price
# 0   Optimum Nutrition (ON) Gold Standard 100% Whey...   3,099
# 1   OPTIMUM NUTRITION Performance Whey Protein Pow...   2,219
# 2   Bigmuscles Nutrition Essential Whey Protein [1...     889
# 3   Bigmuscles Nutrition Premium Gold Whey [1Kg] |...   1,499
# 4   Optimum Nutrition (ON) Gold Standard 100% Whey...   1,741
# 5   Bigmuscles Nutrition Crude Whey - 1 kg (Rich C...   1,099
# 6   The Whole Truth Whey Protein Isolate+Concentra...   3,099
# 7   Carbamide Forte Whey Isolate Matrix | Whey Pro...   1,899
# 8   Optimum Nutrition (ON) Gold Standard 100% Whey...  11,544
# 9   Carbamide Forte Whey Protein Powder Isolate |1...   2,095
# 10  XLR8 Whey Protein, Protein Powder with 24 g Pr...   1,697
# 11  WHEYMILL 100% Whey Protein | 25g Protein, 3g C...   1,399
# 12  NUTRABAY Pure 100% Raw Whey Protein Concentrat...   1,029
# 13  NAKPRO Perform Whey Protein Concentrate | 24g ...   1,599
# ...

# %%
for j in range(1,26):
    URL = "https://www.amazon.in/s?k=whey+protein&i=todays-deals&crid=K8YF2KWBRM5A&sprefix=%2Ctodays-deals%2C232&ref=nb_sb_ss_recent_2_0_recent"
    HEADERS = ({'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/129.0.0.0 Safari/537.36','Accept-Language':'en-US, en;q=0.5'})
    webpage = requests.get(URL, headers=HEADERS)
    soup = BeautifulSoup(webpage.content,"html.parser")
    company = soup.find_all('div',class_="puis-card-container s-card-container s-overflow-hidden aok-relative puis-include-content-margin puis puis-v2fl5pkubaqu126k6zseo6li6q s-latency-cf-section puis-card-border")
    name = []
    price = []
    for i in company:

        name.append(i.find('h2',class_="a-size-mini a-spacing-none a-color-base s-line-clamp-2").text.strip())
        price.append(i.find('span',class_='a-price-whole').text.strip())
    dict1 = {'name':name, 'price':price}
    df1 = pd.DataFrame(dict1)
    
df1
# Out:
#                                                  name   price
# 0   Optimum Nutrition (ON) Gold Standard 100% Whey...   3,099
# 1   OPTIMUM NUTRITION Performance Whey Protein Pow...   2,219
# 2   Bigmuscles Nutrition Essential Whey Protein [1...     889
# 3   Bigmuscles Nutrition Premium Gold Whey [1Kg] |...   1,499
# 4   Optimum Nutrition (ON) Gold Standard 100% Whey...   1,741
# 5   Bigmuscles Nutrition Crude Whey - 1 kg (Rich C...   1,099
# 6   The Whole Truth Whey Protein Isolate+Concentra...   3,099
# 7   Carbamide Forte Whey Isolate Matrix | Whey Pro...   1,899
# 8   Optimum Nutrition (ON) Gold Standard 100% Whey...  11,544
# 9   Carbamide Forte Whey Protein Powder Isolate |1...   2,095
# 10  XLR8 Whey Protein, Protein Powder with 24 g Pr...   1,697
# 11  WHEYMILL 100% Whey Protein | 25g Protein, 3g C...   1,399
# 12  NUTRABAY Pure 100% Raw Whey Protein Concentrat...   1,029
# 13  NAKPRO Perform Whey Protein Concentrate | 24g ...   1,599
# ...

# %%
company = soup.find_all('div',class_="puis-card-container s-card-container s-overflow-hidden aok-relative puis-include-content-margin puis puis-v2fl5pkubaqu126k6zseo6li6q s-latency-cf-section puis-card-border")
len(company)
# Out:
# 16

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# Initialize empty lists to store the scraped data
name = []
price = []

# Iterate through pages 1 to 25
for j in range(1, 26):
    # Update the URL to include the page number
    URL = f"https://www.amazon.in/s?k=whey+protein&i=todays-deals&crid=K8YF2KWBRM5A&sprefix=%2Ctodays-deals%2C232&ref=nb_sb_ss_recent_2_0_recent&page={j}"
    
    HEADERS = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/129.0.0.0 Safari/537.36',
        'Accept-Language': 'en-US, en;q=0.5'
    }
    
    # Get the webpage content
    webpage = requests.get(URL, headers=HEADERS)
    soup = BeautifulSoup(webpage.content, "html.parser")
    
    # Find the product cards
    company = soup.find_all('div', class_="puis-card-container s-card-container s-overflow-hidden aok-relative puis-include-content-margin puis puis-v2fl5pkubaqu126k6zseo6li6q s-latency-cf-section puis-card-border")
    
    # Scrape product names and prices from the current page
    for i in company:
        # Scrape product name
        product_name = i.find('h2', class_="a-size-mini a-spacing-none a-color-base s-line-clamp-2")
        if product_name:
            name.append(product_name.text.strip())
        else:
            name.append("N/A")  # If name is missing, append "N/A"
        
        # Scrape product price
        product_price = i.find('span', class_='a-price-whole')
        if product_price:
            price.append(product_price.text.strip())
        else:
            price.append("N/A")  # If price is missing, append "N/A"

# Create a DataFrame from the scraped data
dict1 = {'name': name, 'price': price}
df1 = pd.DataFrame(dict1)

# Display the DataFrame
df1
# Out:
#                                                   name  price
# 0    Optimum Nutrition (ON) Gold Standard 100% Whey...  3,099
# 1    OPTIMUM NUTRITION Performance Whey Protein Pow...  2,219
# 2    Bigmuscles Nutrition Essential Whey Protein [1...    889
# 3    Bigmuscles Nutrition Premium Gold Whey [1Kg] |...  1,499
# 4    Optimum Nutrition (ON) Gold Standard 100% Whey...  1,741
# ..                                                 ...    ...
# 388  MUSCLEBOLT Mass Booster Gainer 30 Tablets, Inc...    299
# 389  Ripped Up Nutrition Conquer Xtreme Pre- Workou...  2,231
# 390  Nutrition Planet Xtreme Mass Gainer powder Wit...  2,549
# 391  Nutrition Planet Xtreme Mass Gainer With Added...  2,549
# 392  Nirvasa 100% Natural Plant Protein for Pre and...    799
#
# [393 rows x 2 columns]

# %%
df1.to_csv('amazon_whey_protein.csv', index=False)
